# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("DATA/stroke_data.csv")

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  58.0             1              0          Yes        Private
# 1  Female  70.0             0              0          Yes        Private
# 2  Female  52.0             0              0          Yes        Private
# 3  Female  75.0             0              1          Yes  Self-employed
# 4  Female  32.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban              87.96  39.2     never smoked       0
# 1          Rural              69.04  35.9  formerly smoked       0
# 2          Urban              77.59  17.7  formerly smoked       0
# 3          Rural             243.53  27.0     never smoked       0
# 4          Rural              77.67  32.3           smokes       0

# %%
sns.pairplot(data=df)

# %%
sns.heatmap(data=df.isnull(),yticklabels=False,cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
gender = pd.get_dummies(data=df['gender'],drop_first=True)

# %%
gender = gender.convert_dtypes(convert_boolean=False)

# %%
df2 = pd.concat([df,gender],axis=1)

# %%
df2
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  58.0             1              0          Yes        Private
# 1      Female  70.0             0              0          Yes        Private
# 2      Female  52.0             0              0          Yes        Private
# 3      Female  75.0             0              1          Yes  Self-employed
# 4      Female  32.0             0              0          Yes        Private
# ...       ...   ...           ...            ...          ...            ...
# 29060  Female  10.0             0              0           No       children
# 29061  Female  56.0             0              0          Yes       Govt_job
# 29062  Female  82.0             1              0          Yes        Private
# 29063    Male  40.0             0              0          Yes        Private
# 29064  Female  82.0             0              0          Yes        Private
#
# ...

# %%
df2 = df2.drop('gender',axis=1)

# %%
df2.head()
# Out:
#     age  hypertension  heart_disease ever_married      work_type  \
# 0  58.0             1              0          Yes        Private
# 1  70.0             0              0          Yes        Private
# 2  52.0             0              0          Yes        Private
# 3  75.0             0              1          Yes  Self-employed
# 4  32.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke  Male
# 0          Urban              87.96  39.2     never smoked       0     1
# 1          Rural              69.04  35.9  formerly smoked       0     0
# 2          Urban              77.59  17.7  formerly smoked       0     0
# 3          Rural             243.53  27.0     never smoked       0     0
# 4          Rural              77.67  32.3           smokes       0     0

# %%
df2['Residence_type'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
residence_type = (pd.get_dummies(data=df2['Residence_type'],drop_first=True)).convert_dtypes(convert_boolean=False)

# %%
residence_type
# Out:
#        Urban
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 29060      1
# 29061      1
# 29062      1
# 29063      1
# 29064      1
#
# [29065 rows x 1 columns]

# %%
df2 = pd.concat([df2,residence_type],axis=1)

# %%
df2
# Out:
#         age  hypertension  heart_disease ever_married      work_type  \
# 0      58.0             1              0          Yes        Private
# 1      70.0             0              0          Yes        Private
# 2      52.0             0              0          Yes        Private
# 3      75.0             0              1          Yes  Self-employed
# 4      32.0             0              0          Yes        Private
# ...     ...           ...            ...          ...            ...
# 29060  10.0             0              0           No       children
# 29061  56.0             0              0          Yes       Govt_job
# 29062  82.0             1              0          Yes        Private
# 29063  40.0             0              0          Yes        Private
# 29064  82.0             0              0          Yes        Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke  Male  \
# ...

# %%
df2 = df2.drop("Residence_type",axis=1)

# %%
df2
# Out:
#         age  hypertension  heart_disease ever_married      work_type  \
# 0      58.0             1              0          Yes        Private
# 1      70.0             0              0          Yes        Private
# 2      52.0             0              0          Yes        Private
# 3      75.0             0              1          Yes  Self-employed
# 4      32.0             0              0          Yes        Private
# ...     ...           ...            ...          ...            ...
# 29060  10.0             0              0           No       children
# 29061  56.0             0              0          Yes       Govt_job
# 29062  82.0             1              0          Yes        Private
# 29063  40.0             0              0          Yes        Private
# 29064  82.0             0              0          Yes        Private
#
#        avg_glucose_level   bmi   smoking_status  stroke  Male  Urban
# 0                  87.96  39.2     never smoked       0     1      1
# ...

# %%
sns.countplot(data=df2, x='hypertension', hue='stroke')
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
df['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
work_type = (pd.get_dummies(data=df2['work_type'], drop_first=True)).convert_dtypes(convert_boolean=False)

# %%
df2 = pd.concat([df2,work_type],axis=1)

# %%
df2.head()
# Out:
#     age  hypertension  heart_disease ever_married      work_type  \
# 0  58.0             1              0          Yes        Private
# 1  70.0             0              0          Yes        Private
# 2  52.0             0              0          Yes        Private
# 3  75.0             0              1          Yes  Self-employed
# 4  32.0             0              0          Yes        Private
#
#    avg_glucose_level   bmi   smoking_status  stroke  Male  Urban  \
# 0              87.96  39.2     never smoked       0     1      1
# 1              69.04  35.9  formerly smoked       0     0      0
# 2              77.59  17.7  formerly smoked       0     0      1
# 3             243.53  27.0     never smoked       0     0      0
# 4              77.67  32.3           smokes       0     0      0
#
#    Never_worked  Private  Self-employed  children
# 0             0        1              0         0
# 1             0        1              0         0
# ...

# %%
df2 = df2.drop('work_type',axis=1)

# %%
df2
# Out:
#         age  hypertension  heart_disease ever_married  avg_glucose_level  \
# 0      58.0             1              0          Yes              87.96
# 1      70.0             0              0          Yes              69.04
# 2      52.0             0              0          Yes              77.59
# 3      75.0             0              1          Yes             243.53
# 4      32.0             0              0          Yes              77.67
# ...     ...           ...            ...          ...                ...
# 29060  10.0             0              0           No              58.64
# 29061  56.0             0              0          Yes             213.61
# 29062  82.0             1              0          Yes              91.94
# 29063  40.0             0              0          Yes              99.16
# 29064  82.0             0              0          Yes              79.48
#
#         bmi   smoking_status  stroke  Male  Urban  Never_worked  Private  \
# ...

# %%
df['ever_married'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
ever_married = (pd.get_dummies(df['ever_married'],drop_first=True)).convert_dtypes(convert_boolean=False)

# %%
ever_married.columns = ['Ever_Married']

# %%
ever_married
# Out:
#        Ever_Married
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 29060             0
# 29061             1
# 29062             1
# 29063             1
# 29064             1
#
# [29065 rows x 1 columns]

# %%
df2 = pd.concat([ever_married,df2],axis=1)

# %%
df2
# Out:
#        Ever_Married   age  hypertension  heart_disease ever_married  \
# 0                 1  58.0             1              0          Yes
# 1                 1  70.0             0              0          Yes
# 2                 1  52.0             0              0          Yes
# 3                 1  75.0             0              1          Yes
# 4                 1  32.0             0              0          Yes
# ...             ...   ...           ...            ...          ...
# 29060             0  10.0             0              0           No
# 29061             1  56.0             0              0          Yes
# 29062             1  82.0             1              0          Yes
# 29063             1  40.0             0              0          Yes
# 29064             1  82.0             0              0          Yes
#
#        avg_glucose_level   bmi   smoking_status  stroke  Male  Urban  \
# 0                  87.96  39.2     never smoked       0     1      1
# ...

# %%
df2 = df2.drop('ever_married',axis=1)

# %%
df2.head(2)
# Out:
#    Ever_Married   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0             1  58.0             1              0              87.96  39.2
# 1             1  70.0             0              0              69.04  35.9
#
#     smoking_status  stroke  Male  Urban  Never_worked  Private  Self-employed  \
# 0     never smoked       0     1      1             0        1              0
# 1  formerly smoked       0     0      0             0        1              0
#
#    children
# 0         0
# 1         0

# %%
stroke_ = df2['stroke']

# %%
df['smoking_status'].unique()
# Out:
# array(['never smoked', 'formerly smoked', 'smokes'], dtype=object)

# %%
smoking_status = (pd.get_dummies(data=df['smoking_status'],drop_first=True)).convert_dtypes(convert_boolean=False)

# %%
smoking_status
# Out:
#        never smoked  smokes
# 0                 1       0
# 1                 0       0
# 2                 0       0
# 3                 1       0
# 4                 0       1
# ...             ...     ...
# 29060             1       0
# 29061             0       0
# 29062             0       0
# 29063             1       0
# 29064             1       0
#
# [29065 rows x 2 columns]

# %%
df2 = pd.concat([df2,smoking_status],axis=1)

# %%
df2.head(2)
# Out:
#    Ever_Married   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0             1  58.0             1              0              87.96  39.2
# 1             1  70.0             0              0              69.04  35.9
#
#     smoking_status  stroke  Male  Urban  Never_worked  Private  Self-employed  \
# 0     never smoked       0     1      1             0        1              0
# 1  formerly smoked       0     0      0             0        1              0
#
#    children  never smoked  smokes
# 0         0             1       0
# 1         0             0       0

# %%
df2 = df2.drop('smoking_status',axis=1)

# %%
df2
# Out:
#        Ever_Married   age  hypertension  heart_disease  avg_glucose_level  \
# 0                 1  58.0             1              0              87.96
# 1                 1  70.0             0              0              69.04
# 2                 1  52.0             0              0              77.59
# 3                 1  75.0             0              1             243.53
# 4                 1  32.0             0              0              77.67
# ...             ...   ...           ...            ...                ...
# 29060             0  10.0             0              0              58.64
# 29061             1  56.0             0              0             213.61
# 29062             1  82.0             1              0              91.94
# 29063             1  40.0             0              0              99.16
# 29064             1  82.0             0              0              79.48
#
#         bmi  stroke  Male  Urban  Never_worked  Private  Self-employed  \
# ...

# %%
df2 = df2.drop('stroke',axis=1)

# %%
df2
# Out:
#        Ever_Married   age  hypertension  heart_disease  avg_glucose_level  \
# 0                 1  58.0             1              0              87.96
# 1                 1  70.0             0              0              69.04
# 2                 1  52.0             0              0              77.59
# 3                 1  75.0             0              1             243.53
# 4                 1  32.0             0              0              77.67
# ...             ...   ...           ...            ...                ...
# 29060             0  10.0             0              0              58.64
# 29061             1  56.0             0              0             213.61
# 29062             1  82.0             1              0              91.94
# 29063             1  40.0             0              0              99.16
# 29064             1  82.0             0              0              79.48
#
#         bmi  Male  Urban  Never_worked  Private  Self-employed  children  \
# ...

# %%
df2 = pd.concat([df2,stroke_],axis=1)

# %%
df2 = df2.drop('stroke',axis=1)

# %%
df2
# Out:
#        Ever_Married   age  hypertension  heart_disease  avg_glucose_level  \
# 0                 1  58.0             1              0              87.96
# 1                 1  70.0             0              0              69.04
# 2                 1  52.0             0              0              77.59
# 3                 1  75.0             0              1             243.53
# 4                 1  32.0             0              0              77.67
# ...             ...   ...           ...            ...                ...
# 29060             0  10.0             0              0              58.64
# 29061             1  56.0             0              0             213.61
# 29062             1  82.0             1              0              91.94
# 29063             1  40.0             0              0              99.16
# 29064             1  82.0             0              0              79.48
#
#         bmi  Male  Urban  Never_worked  Private  Self-employed  children  \
# ...

# %%
X = df2.drop('stroke',axis=1).values
y = df2['stroke'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test[6732]
# Out:
# array([1.        , 0.98611111, 0.        , 0.        , 0.26681918,
#        0.29277567, 0.        , 0.        , 0.        , 1.        ,
#        0.        , 0.        , 1.        , 0.        ])

# %%
X_train.shape
# Out:
# (20345, 14)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model = Sequential()

model.add(Dense(14,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(14,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(7,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(7,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=1,activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',mode=min, verbose=1,patience=25)
# Out:
# WARNING:tensorflow:EarlyStopping mode <built-in function min> is unknown, fallback to auto mode.

# %%
model.fit(x=X_train,y=y_train,epochs=25,batch_size=128,validation_data=(X_test,y_test))
# Out:
# Epoch 1/25
# 159/159 [==============================] - 4s 7ms/step - loss: 0.4368 - val_loss: 0.1005
# Epoch 2/25
# 159/159 [==============================] - 1s 5ms/step - loss: 0.2767 - val_loss: 0.0886
# Epoch 3/25
# 159/159 [==============================] - 1s 6ms/step - loss: 0.2246 - val_loss: 0.0856
# Epoch 4/25
# 159/159 [==============================] - 1s 6ms/step - loss: 0.1767 - val_loss: 0.0846
# Epoch 5/25
# 159/159 [==============================] - 1s 5ms/step - loss: 0.1523 - val_loss: 0.0839
# Epoch 6/25
# 159/159 [==============================] - 1s 5ms/step - loss: 0.1407 - val_loss: 0.0837
# Epoch 7/25
# 159/159 [==============================] - 1s 5ms/step - loss: 0.1374 - val_loss: 0.0838
# Epoch 8/25
# 159/159 [==============================] - 1s 5ms/step - loss: 0.1313 - val_loss: 0.0837
# Epoch 9/25
# 159/159 [==============================] - 1s 5ms/step - loss: 0.1319 - val_loss: 0.0837
# Epoch 10/25
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#         loss  val_loss
# 0   0.385490  0.095883
# 1   0.133203  0.087318
# 2   0.114379  0.085329
# 3   0.107922  0.084280
# 4   0.104858  0.083798
# 5   0.103397  0.083417
# 6   0.102678  0.083078
# 7   0.102743  0.082711
# 8   0.099635  0.082891
# 9   0.100656  0.081973
# 10  0.099602  0.081514
# 11  0.097234  0.080879
# 12  0.097621  0.081154
# 13  0.096172  0.080564
# 14  0.096331  0.079672
# 15  0.094720  0.079336
# 16  0.095390  0.079134
# 17  0.094694  0.079098
# 18  0.091869  0.078418
# 19  0.092161  0.078166
# 20  0.093505  0.078148
# 21  0.091761  0.078392
# 22  0.090857  0.077363
# 23  0.091301  0.077107
# 24  0.089814  0.076799

# %%
losses.plot()
# Out:
# <Axes: >

# %%
model.fit(x=X_train,y=y_train,epochs=600,batch_size=128,validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Epoch 1/600
# 159/159 [==============================] - 1s 6ms/step - loss: 0.1032 - val_loss: 0.0799
# Epoch 2/600
# 159/159 [==============================] - 1s 5ms/step - loss: 0.1014 - val_loss: 0.0796
# Epoch 3/600
# 159/159 [==============================] - 1s 5ms/step - loss: 0.1026 - val_loss: 0.0797
# Epoch 4/600
# 159/159 [==============================] - 1s 5ms/step - loss: 0.0994 - val_loss: 0.0791
# Epoch 5/600
# 159/159 [==============================] - 1s 5ms/step - loss: 0.0999 - val_loss: 0.0795
# Epoch 6/600
# 159/159 [==============================] - 1s 5ms/step - loss: 0.0976 - val_loss: 0.0790
# Epoch 7/600
# 159/159 [==============================] - 1s 5ms/step - loss: 0.0974 - val_loss: 0.0792
# Epoch 8/600
# 159/159 [==============================] - 1s 6ms/step - loss: 0.0969 - val_loss: 0.0788
# Epoch 9/600
# 159/159 [==============================] - 1s 6ms/step - loss: 0.0946 - val_loss: 0.0784
# Epoch 10/600
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions = model.predict(X_test)

predicted_classes =np.where(predictions > 0.03, 1,0)
# Out:
# 273/273 [==============================] - 1s 4ms/step

# %%
predicted_classes
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]])

# %%
print(confusion_matrix(y_test,predicted_classes))
# Out:
# [[7139 1431]
#  [  61   89]]

# %%
print(classification_report(y_test,predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.83      0.91      8570
#            1       0.06      0.59      0.11       150
#
#     accuracy                           0.83      8720
#    macro avg       0.53      0.71      0.51      8720
# weighted avg       0.98      0.83      0.89      8720

# %%
np.where((model.predict(X_test)[6732]) > 0.05, 1,0)
# Out:
# 273/273 [==============================] - 1s 2ms/step
# array([1])

# %%
y_testdf = pd.DataFrame(y_test)

# %%
y_testdf[0].sort_values()
# Out:
# 0       0
# 5793    0
# 5792    0
# 5791    0
# 5790    0
#        ..
# 6732    1
# 5221    1
# 5222    1
# 7284    1
# 7564    1
# Name: 0, Length: 8720, dtype: int64

# %%
model.predict(X_test)[6732]
# Out:
# 273/273 [==============================] - 1s 2ms/step
# array([0.05546115], dtype=float32)

# %%
predictions.max()
# Out:
# 0.054052576
